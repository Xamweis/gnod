# %%
import pandas as pd
import numpy as np
import pickle

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("../secrets/secrets.txt","r")
string = secrets_file.read()
secrets_file.close()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
a = pd.read_csv('../songs_csv/jan.csv')
b = pd.read_csv('../songs_csv/willis.csv')

x = pd.read_csv('../songs_csv/mine.csv')

cluster_features = [
    'danceability', 'energy', 'loudness', 'speechiness', 
    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms'
    ]
all = pd.concat([a,b,x],axis=0).drop_duplicates(subset=['id']).dropna(subset=cluster_features)

# fill preview-nans:
all['preview'] = all['preview'].fillna('No preview URL')

# shuffle the df and reset its index
all = all.sample(frac=1).reset_index(drop=True)
all
# Out:
#                                            track_name              artist  \
# 0                                           DAMN GURL        DirtySnatcha
# 1                                          Libertango     Astor Piazzolla
# 2                                      Sandy Fishnets       Evelyn Evelyn
# 3                                            Deadfuck             Gorgasm
# 4                                Since I Fell for You               Thyra
# ...                                               ...                 ...
# 335138                                    שירת העשבים          HaGevatron
# 335139  Kanjadalaayataakshi Kamakshi - Manohari - Adi  M. S. Subbulakshmi
# 335140                      Afroman Is Coming to Town             Afroman
# 335141                       A nos disparus - Zouglou      Les Garagistes
# 335142                      RING RING (feat. william)              Cledos
#
#                             id  danceability  energy   key  loudness  mode  \
# 0       1itKR2sJ964spIdicNdADo         0.690   0.979   7.0    -0.408   1.0
# 1       1IIydYQ6LTzZpgLXYpNlNy         0.600   0.492   9.0   -12.463   0.0
# 2       3XkeLtS2RZuxZLk8StKcAE         0.327   0.283   0.0   -11.425   0.0
# 3       3jfDUHyLmcjXyqjo2NhCGW         0.273   0.995   1.0    -4.728   0.0
# 4       2l3ZK5sNfKVCa1JZBVeAnR         0.342   0.367   1.0   -10.225   0.0
# ...                        ...           ...     ...   ...       ...   ...
# 335138  3ebsZ2OMUjBoEzvX49T49h         0.382   0.256   5.0   -12.881   0.0
# 335139  1LRaV6xCjFF6uT9PAxCZD4         0.398   0.408   7.0   -17.935   1.0
# 335140  5u6FZVhkIc9Kp5zjVQ69zr         0.954   0.432  10.0    -7.663   1.0
# 335141  4zAffSXJVXbj4jZpZI7wBU         0.556   0.396   0.0   -12.152   1.0
# 335142  4KIxCx1YugpjTipl6sVcP9         0.639   0.630   5.0    -9.800   0.0
#
#         speechiness  acousticness  ...  valence    tempo            type  \
# 0            0.1940      0.000060  ...    0.200  150.182  audio_features
# 1            0.0275      0.278000  ...    0.543  139.296  audio_features
# 2            0.0326      0.928000  ...    0.142  123.495  audio_features
# 3            0.1220      0.000035  ...    0.125  123.607  audio_features
# 4            0.0392      0.524000  ...    0.446  188.000  audio_features
# ...             ...           ...  ...      ...      ...             ...
# 335138       0.0296      0.814000  ...    0.158  125.068  audio_features
# 335139       0.1990      0.986000  ...    0.614   90.061  audio_features
# 335140       0.2140      0.105000  ...    0.569  122.719  audio_features
# 335141       0.0516      0.004870  ...    0.360  120.043  audio_features
# 335142       0.1060      0.016400  ...    0.245  166.062  audio_features
#
#                           id.1                                   uri  \
# 0       1itKR2sJ964spIdicNdADo  spotify:track:1itKR2sJ964spIdicNdADo
# 1       1IIydYQ6LTzZpgLXYpNlNy  spotify:track:1IIydYQ6LTzZpgLXYpNlNy
# 2       3XkeLtS2RZuxZLk8StKcAE  spotify:track:3XkeLtS2RZuxZLk8StKcAE
# 3       3jfDUHyLmcjXyqjo2NhCGW  spotify:track:3jfDUHyLmcjXyqjo2NhCGW
# 4       2l3ZK5sNfKVCa1JZBVeAnR  spotify:track:2l3ZK5sNfKVCa1JZBVeAnR
# ...                        ...                                   ...
# 335138  3ebsZ2OMUjBoEzvX49T49h  spotify:track:3ebsZ2OMUjBoEzvX49T49h
# 335139  1LRaV6xCjFF6uT9PAxCZD4  spotify:track:1LRaV6xCjFF6uT9PAxCZD4
# 335140  5u6FZVhkIc9Kp5zjVQ69zr  spotify:track:5u6FZVhkIc9Kp5zjVQ69zr
# 335141  4zAffSXJVXbj4jZpZI7wBU  spotify:track:4zAffSXJVXbj4jZpZI7wBU
# 335142  4KIxCx1YugpjTipl6sVcP9  spotify:track:4KIxCx1YugpjTipl6sVcP9
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/1itKR2sJ964s...
# 1       https://api.spotify.com/v1/tracks/1IIydYQ6LTzZ...
# 2       https://api.spotify.com/v1/tracks/3XkeLtS2RZux...
# 3       https://api.spotify.com/v1/tracks/3jfDUHyLmcjX...
# 4       https://api.spotify.com/v1/tracks/2l3ZK5sNfKVC...
# ...                                                   ...
# 335138  https://api.spotify.com/v1/tracks/3ebsZ2OMUjBo...
# 335139  https://api.spotify.com/v1/tracks/1LRaV6xCjFF6...
# 335140  https://api.spotify.com/v1/tracks/5u6FZVhkIc9K...
# 335141  https://api.spotify.com/v1/tracks/4zAffSXJVXbj...
# 335142  https://api.spotify.com/v1/tracks/4KIxCx1Yugpj...
#
#                                              analysis_url duration_ms  \
# 0       https://api.spotify.com/v1/audio-analysis/1itK...    160817.0
# 1       https://api.spotify.com/v1/audio-analysis/1IIy...    166104.0
# 2       https://api.spotify.com/v1/audio-analysis/3Xke...    425253.0
# 3       https://api.spotify.com/v1/audio-analysis/3jfD...    224653.0
# 4       https://api.spotify.com/v1/audio-analysis/2l3Z...    240301.0
# ...                                                   ...         ...
# 335138  https://api.spotify.com/v1/audio-analysis/3ebs...    213987.0
# 335139  https://api.spotify.com/v1/audio-analysis/1LRa...    453799.0
# 335140  https://api.spotify.com/v1/audio-analysis/5u6F...    138160.0
# 335141  https://api.spotify.com/v1/audio-analysis/4zAf...    372637.0
# 335142  https://api.spotify.com/v1/audio-analysis/4KIx...    150787.0
#
#        time_signature                                            preview
# 0                 4.0  https://p.scdn.co/mp3-preview/78db96949ada62d2...
# 1                 4.0  https://p.scdn.co/mp3-preview/c88461032c331cea...
# 2                 3.0  https://p.scdn.co/mp3-preview/2415d5ceed124db0...
# 3                 4.0  https://p.scdn.co/mp3-preview/dbb21ce2da91fe28...
# 4                 3.0  https://p.scdn.co/mp3-preview/8884af677155f289...
# ...               ...                                                ...
# 335138            4.0  https://p.scdn.co/mp3-preview/9c92c3f90df0a5f5...
# 335139            4.0  https://p.scdn.co/mp3-preview/94e81ee2e7285f2e...
# 335140            5.0                                     No preview URL
# 335141            4.0  https://p.scdn.co/mp3-preview/c0efcc6eb46275a5...
# 335142            4.0                                     No preview URL
#
# [335143 rows x 22 columns]

# %%
billboard_100 = pd.read_csv('top100_billboard.csv')
billboard_100 = billboard_100.rename(columns={
    'Title': 'track_name',
    'Artist': 'artist'
})
billboard_100['preview'] = ['No preview URL' for _ in range(len(billboard_100))]

# %%
def ask_user():
    while True:
        user_song = input('ENTER YOUR SONG!')
        if user_song == '':
            continue
        user_artist = input('ENTER THE ARTIST!')
        if user_artist == '':
            continue
        else:
            return user_song, user_artist

# %%
def delete_from_top100(song, artist, top100:pd.DataFrame):
    song_artist = top100[top100['track_name'].str.lower() == song.lower()]['artist'].str.lower()
    if len(song_artist) < 1:
        return top100

    elif artist.lower() in song_artist.values:
        top100 = top100[~((top100['track_name'].str.lower() == song.lower())&(top100['artist'].str.lower() == artist.lower()))]
    
    return top100

# %%
def get_song_uri(song, artist):
    track = sp.search(q=f"remaster%20track:{song}%20artist:{artist}", type='track', limit=1)['tracks']['items']
    if len(track) > 0:
        return track[0]['uri']
    else:
        return

# %%
def get_cluster_features(uri, spotifyclient:spotipy.Spotify):
    features = pd.json_normalize(spotifyclient.audio_features(uri))
    return features.reset_index(drop=True)

# %%
def recommend_song_from_top100(song, artist, top100:pd.DataFrame):
    top100 = top100[~((top100['track_name'].str.lower() == song.lower()) &(top100['artist'].str.lower() == artist.lower()))]
    return top100.sample(n=1)

# %%
def recommend_song_from_cluster(df:pd.DataFrame, clust: int, clustcol='cluster'):
    return df[df[clustcol]==clust].sample(n=1)

# %%
def RECOMMENDER_3000(song, artist, top100, database, client, model, cluster_features, scaler):
    print('Your song was:', song, 'by', artist)
    new_top100 = delete_from_top100(song, artist, top100)
    
    if len(new_top100) != len(top100):
        rec = recommend_song_from_top100(song, artist, top100)
        print('Your song is in the TOP 100, check another one out:')

    else:
        database_scaled_features = scaler.transform(database[cluster_features])
        database = database.drop(['cluster'], axis=1, errors='ignore')
        database['cluster'] = model.predict(database_scaled_features)

        song_uri = get_song_uri(song, artist)
        if not song_uri:
            print('Song not found on spotify!')
            return
        features = get_cluster_features(song_uri, client)[cluster_features]
        scaled = scaler.transform(features)
        song_cluster = model.predict(scaled)[0]
        rec = recommend_song_from_cluster(database, song_cluster)
        print('You have a nice taste in music, check out this one:')

    print(rec['track_name'].values[0], 'by', rec['artist'].values[0])
    print(rec['preview'].values[0])

# %%
from sklearn.preprocessing import StandardScaler

# filter out all the numericals
nums = all.select_dtypes(include=np.number)
# time_signature & key only few values --> categorical
nums = nums.drop(['time_signature', 'key', 'mode'], axis=1)

scaler = StandardScaler().fit(nums)
scaled = scaler.transform(nums)

# %%
from sklearn import cluster

kmeans = cluster.KMeans(n_clusters=8)
kmeans.fit(scaled)

# %%
song, artist = ask_user()

# %%
RECOMMENDER_3000(song, artist, billboard_100, all, sp, kmeans, cluster_features, scaler)
# Out:
# Your song was: s by s
# Song not found on spotify!
