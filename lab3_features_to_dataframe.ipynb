# %%
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets/secrets.txt","r")
string = secrets_file.read()
secrets_file.close()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

def flatten_to_artist(input_list):
    return [item[1] for sublist in input_list for item in sublist]

def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        # sleep(randint(100,1000)/1000)
    return tracks

# %%
# mytracks = get_playlist_tracks('05Tli1k3x5YQEvNZyOcR4Z') # wixderwoche
# mytracks = get_playlist_tracks('4rnleEAOdmFAbRcNCgZMpY') # jan
mytracks = get_playlist_tracks('5S8SJdl1BDc0ugpkEvFsIL') # willis orr (10,000 songs)

# %%
mytracks_artists = [get_name_artist_from_playlist_item(mytrack) for mytrack in mytracks]

my_artists = flatten_to_artist(mytracks_artists)

# drop duplicate artists
my_artists_unique = list(set(my_artists))
# my_artists_unique = []
# [my_artists_unique.append(artist.strip()) for artist in my_artists if artist.strip() not in my_artists_unique]

display(len(my_artists_unique))
# Out:
# 4328

# %%
import json

# %%
counter = 0
batch_size = 250

for i in range(0, len(my_artists_unique), batch_size):
    start = i
    stop = i + batch_size

    for my_artist in my_artists_unique[start:stop]:

            print(f'fetching {counter:5.0f}:  ', my_artist)
            counter += 1
            
            try:
                tr = sp.search(q=f'artist:{my_artist}', type='track', limit=20)['tracks']['items']

                if len(tr) > 0:
                    for t in tr:
                        song = {}
                        features = sp.audio_features(t['uri'])
                        
                        song['track_name'] = t['name']
                        song['artist'] = my_artist
                        song['id'] = t['id']
                        song_pd = pd.DataFrame([song])

                        song_pd = pd.concat([song_pd, pd.json_normalize(features[0])], axis=1)
                        if counter == 1:
                            songs = song_pd
                        else:
                            songs = pd.concat([songs, song_pd], axis=0)
            except:
                print('something went wrong')
                continue            
    songs.reset_index(drop=True).to_csv(f'csv_data/willis_{counter}.csv', index=False)
# Out:
# fetching     0:
# fetching     1:   Novo Amor
# fetching     2:   Bill Conti
# fetching     3:   James Taylor
# fetching     4:   Matt Simons
# fetching     5:   Angus & Julia Stone
# fetching     6:   Asaf Avidan & the Mojos
# fetching     7:   London Philharmonic Orchestra
# fetching     8:   Gabe Real
# fetching     9:   Echoman
# fetching    10:   Janieck Devy
# fetching    11:   Jake Isaac
# fetching    12:   Frederic Riesterer
# fetching    13:   MF DOOM
# fetching    14:   Paul Schuurman
# fetching    15:   SushiCatz
# fetching    16:   Cardi B
# fetching    17:   Dean Lewis
# fetching    18:   As Tall As Lions
# fetching    19:   Tyga
# fetching    20:   Approaching Nirvana
# fetching    21:   The Jungle Giants
# fetching    22:   Prins
# fetching    23:   Dobie Gray
# fetching    24:   Frank Sinatra
# fetching    25:   Christina Perri
# fetching    26:   Red Hot Chili Peppers
# fetching    27:   Danny Gokey
# fetching    28:   Capcom Sound Team
# fetching    29:   Life Sounds Nature
# fetching    30:   Ron Pope
# fetching    31:   Tammi Terrell
# fetching    32:   Ghost Town DJs
# fetching    33:   Lil Xan
# fetching    34:   Bon Iver
# fetching    35:   Bingo Players
# fetching    36:   Phosphorescent
# fetching    37:   Jennie A.
# fetching    38:   Sade
# fetching    39:   Big Daddy Weave
# fetching    40:   Bahari
# fetching    41:   Knife Party
# fetching    42:   Jay Pryor
# fetching    43:   Canopy Climbers
# fetching    44:   Niall Horan
# fetching    45:   Lecrae
# fetching    46:   The Polish Ambassador
# fetching    47:   Beach House
# fetching    48:   John The Blind
# fetching    49:   Tom Waits
# fetching    50:   The Chainsmokers
# fetching    51:   AmaLee
# fetching    52:   Jordin Sparks
# fetching    53:   Phillip Phillips
# fetching    54:   Jabba
# fetching    55:   Hillsong Young & Free
# fetching    56:   ScHoolboy Q
# fetching    57:   Charli XCX
# fetching    58:   Buffy Sainte-Marie
# fetching    59:   American Authors
# fetching    60:   Jon Pardi
# fetching    61:   Snow
# fetching    62:   OMI
# fetching    63:   Cory Asbury
# fetching    64:   Robert Earl Keen
# fetching    65:   Thirty Seconds To Mars
# fetching    66:   Jars Of Clay
# fetching    67:   The Drums
# fetching    68:   Ace of Base
# fetching    69:   Jaffa
# fetching    70:   Stevie Ray Vaughan
# fetching    71:   The Chordettes
# fetching    72:   The Ting Tings
# fetching    73:   Big & Rich
# fetching    74:   Paul Weston And His Orchestra
# fetching    75:   The Strumbellas
# fetching    76:   Hayla
# fetching    77:   Explosions In The Sky
# fetching    78:   ERIK
# something went wrong
# fetching    79:   Axel Ehnström
# fetching    80:   The Piano Guys
# fetching    81:   The Who
# fetching    82:   Jack Ü
# fetching    83:   Niki & The Dove
# fetching    84:   Hannah Montana
# fetching    85:   Bounty Killer
# fetching    86:   ZHU
# fetching    87:   The Beatles
# fetching    88:   Mike Taylor
# fetching    89:   OneRepublic
# fetching    90:   Kim Lip
# fetching    91:   Kane Brown
# fetching    92:   Father John Misty
# fetching    93:   Erykah Badu
# fetching    94:   Macy Gray
# fetching    95:   Pusha T
# fetching    96:   Phantogram
# fetching    97:   Geoff Zanelli
# fetching    98:   Susana Baca
# fetching    99:   Mase & Puff Daddy
# fetching   100:   Ella Vos
# fetching   101:   Social House
# fetching   102:   Cheryl Lynn
# fetching   103:   Sir Simon Rattle
# fetching   104:   Cathrine Lassen
# fetching   105:   Tessa Odden
# fetching   106:   Tungevaag
# fetching   107:   Kevin Lyttle
# fetching   108:   Duane Eddy
# fetching   109:   Martin Garrix
# fetching   110:   Nile Rodgers
# fetching   111:   Tom Bailey
# fetching   112:   Noah Cyrus
# fetching   113:   Trevor Dayn Dallas
# fetching   114:   PJ Harvey
# fetching   115:   The Megamixers
# fetching   116:   Hellsongs
# fetching   117:   John De Sohn
# fetching   118:   Andrew Bird
# fetching   119:   Beatenberg
# fetching   120:   t.A.T.u.
# fetching   121:   Irma Thomas
# fetching   122:   Jonas Kvarnström
# fetching   123:   James Droll
# fetching   124:   Audiovent
# fetching   125:   Arcade Fire
# fetching   126:   The Dandy Warhols
# fetching   127:   Oscar and the Wolf
# fetching   128:   Garrett Hedlund
# fetching   129:   Captain Cuts
# fetching   130:   Kamilla Wigestrand
# fetching   131:   Widespread Panic
# fetching   132:   Lil Pump
# fetching   133:   Luke Bryan
# fetching   134:   The Greatest Showman Ensemble
# fetching   135:   Car Seat Headrest
# fetching   136:   Rhys Lewis
# fetching   137:   Jean-Michel Jarre
# fetching   138:   Nappy Roots
# fetching   139:   Bobby Day
# fetching   140:   Scatman John
# fetching   141:   Hkeem
# fetching   142:   Providers
# fetching   143:   Maluma
# fetching   144:   Toni Braxton
# fetching   145:   Yasiin Bey
# fetching   146:   Tyler.V
# fetching   147:   Lonestar
# fetching   148:   Nirvana
# fetching   149:   Count Basic
# fetching   150:   YEIN
# fetching   151:   PARTYNEXTDOOR
# fetching   152:   Matt Damon
# fetching   153:   Nate Dogg
# fetching   154:   Booker T. & the M.G.'s
# something went wrong
# fetching   155:   Barenaked Ladies
# something went wrong
# fetching   156:   Nayer
# fetching   157:   CHARLIE310BROWN
# fetching   158:   Kevin Gates
# fetching   159:   Daniel Wilson
# fetching   160:   Mr Wox
# fetching   161:   Pacific Air
# fetching   162:   Preme
# fetching   163:   As Blood Runs Black
# fetching   164:   Wax Tailor
# fetching   165:   Daddy Yankee
# fetching   166:   The Offspring
# fetching   167:   Anna Nalick
# fetching   168:   Nicco
# fetching   169:   Lisa Ajax
# fetching   170:   Queens of the Stone Age
# fetching   171:   James Loughran
# fetching   172:   Shawn Hook
# fetching   173:   Common
# fetching   174:   Avenged Sevenfold
# fetching   175:   Unge Ferrari
# fetching   176:   Tore
# fetching   177:   rOlfFa
# fetching   178:   Wende
# fetching   179:   Jonathan Wilson
# fetching   180:   Fumiko Shiraga
# fetching   181:   Rayvon
# fetching   182:   Daughtry
# fetching   183:   Bruce Springsteen
# fetching   184:   The Vaccines
# fetching   185:   Sivert Høyem
# fetching   186:   Donavon Frankenreiter
# fetching   187:   Them Fangs
# fetching   188:   Johnny Mercer & The Pied Pipers
# fetching   189:   CHVRCHES
# fetching   190:   Sounds Of Nature : Thunderstorm, Rain
# fetching   191:   Alesso
# fetching   192:   Fenix Flexin
# fetching   193:   Colin & Caroline
# fetching   194:   Joy Division
# fetching   195:   Amon Amarth
# fetching   196:   Mike Oldfield
# fetching   197:   Keaton Henson
# fetching   198:   Okkervil River
# fetching   199:   Yung Joc
# fetching   200:   Runaway June
# fetching   201:   Cess
# fetching   202:   Hardwell
# fetching   203:   Nathan Goshen
# fetching   204:   jhfly
# fetching   205:   Solomon Burke
# fetching   206:   Darius Rucker
# fetching   207:   Mads Hansen
# fetching   208:   Elle King
# fetching   209:   Lenka
# fetching   210:   M. Maggie
# fetching   211:   Andy Garcia
# fetching   212:   Kool & The Gang
# fetching   213:   Mark McCabe
# fetching   214:   DJ Frank E
# fetching   215:   The Lightning Seeds
# fetching   216:   On An On
# fetching   217:   Lights & Motion
# fetching   218:   Alex Adair
# fetching   219:   Jacob Sutherland
# fetching   220:   Prince Fox
# fetching   221:   Jenifer Lewis
# fetching   222:   SIX60
# fetching   223:   Blue Metheny
# fetching   224:   Plain White T's
# fetching   225:   Big Black Delta
# fetching   226:   Ponette
# fetching   227:   David Harks
# fetching   228:   John Paesano
# fetching   229:   Ken Scott
# fetching   230:   Electric Octopus
# fetching   231:   Swae Lee
# fetching   232:   Karen O And The Kids
# fetching   233:   LOCASH
# fetching   234:   David Bauer
# fetching   235:   Augustana
# fetching   236:   The Cadillac Three
# fetching   237:   Benny Sings
# fetching   238:   Urban Cone
# fetching   239:   Norman Greenbaum
# fetching   240:   Natalia Lafourcade
# fetching   241:   Great Good Fine Ok
# fetching   242:   De La Soul
# fetching   243:   Lea Rue
# fetching   244:   B-Sights
# fetching   245:   Tori Kelly
# fetching   246:   No Doubt
# fetching   247:   Sleepy Fish
# fetching   248:   George Benson
# fetching   249:   Hit-Boy
# fetching   250:   SwuM
# fetching   251:   Trippie Redd
# fetching   252:   John Lamonica
# fetching   253:   Woodkid
# fetching   254:   Shawn Mendes
# something went wrong
# fetching   255:   Dizzy Mizz Lizzy
# fetching   256:   Three Days Grace
# fetching   257:   Lil Halima
# fetching   258:   Tom Cochrane
# fetching   259:   Classics IV
# fetching   260:   Conor Maynard
# fetching   261:   Randy Houser
# fetching   262:   Chet Baker
# fetching   263:   Chromeo
# fetching   264:   Martin Jensen
# fetching   265:   The Emotions
# fetching   266:   Børud-Gjengen
# fetching   267:   SINY
# fetching   268:   Modern Baseball
# fetching   269:   武田朋子
# fetching   270:   Anna F.
# fetching   271:   Desert Sessions
# fetching   272:   Sixfingerz
# fetching   273:   Cozi Zuehlsdorff
# fetching   274:   Alan Rickman
# fetching   275:   Emilie Nicolas
# fetching   276:   The Tallest Man On Earth
# fetching   277:   Raaban
# fetching   278:   CAZZETTE
# fetching   279:   Liesbeth List
# fetching   280:   DJ Shaan
# fetching   281:   Joe Walsh
# fetching   282:   Zeromancer
# fetching   283:   Buscemi
# fetching   284:   The Magician
# fetching   285:   Stealers Wheel
# fetching   286:   Dimitri Vegas
# fetching   287:   The Cardigans
# fetching   288:   Jerry Jeff Walker
# fetching   289:   Lauren Daigle
# fetching   290:   Ina Wroldsen
# fetching   291:   Hook N Sling
# fetching   292:   Leona Lewis
# fetching   293:   Jasmine Ash
# fetching   294:   Eels
# fetching   295:   DJ Løv
# fetching   296:   Beats & Pieces ft. Fab
# fetching   297:   Crazy Town
# fetching   298:   St. South
# fetching   299:   Lana Del Rey
# fetching   300:   Dzeko
# fetching   301:   Death Team
# fetching   302:   Tritonal
# fetching   303:   Olesya Bi
# something went wrong
# fetching   304:   DCup
# fetching   305:   Amatorski
# fetching   306:   Bro Safari
# fetching   307:   Wafia
# fetching   308:   Rascal Flatts
# fetching   309:   XXXTENTACION
# fetching   310:   Chris Gallery
# fetching   311:   Canon
# fetching   312:   Rachel McDowall
# fetching   313:   Cypress Hill
# fetching   314:   Alela Diane
# fetching   315:   Johnny Depp
# fetching   316:   Mansionair
# fetching   317:   Devvon Terrell
# fetching   318:   Natti Natasha
# fetching   319:   Cassadee Pope
# fetching   320:   Little Dragon
# fetching   321:   James Yuill
# fetching   322:   Jackie Lee
# fetching   323:   The Staple Singers
# fetching   324:   Staysman & Lazz
# fetching   325:   Jayden Bartels
# fetching   326:   The Key of Awesome
# fetching   327:   Jeff Conaway
# fetching   328:   Allen Stone
# fetching   329:   SAYGRACE
# fetching   330:   Travis Tritt
# fetching   331:   De Nalgas
# fetching   332:   Patrick Doyle
# fetching   333:   Elder Island
# fetching   334:   Sonoya Mizuno
# fetching   335:   MINO
# fetching   336:   Tors
# fetching   337:   Whales & This Lake
# fetching   338:   Fred Åkerström
# fetching   339:   RyanDan
# fetching   340:   Ensemble - Tangled
# fetching   341:   311
# fetching   342:   Sugar Ray
# fetching   343:   The Wanted
# fetching   344:   Neck Deep
# fetching   345:   Anjulie
# fetching   346:   Jonathan Coulton
# fetching   347:   Korn
# fetching   348:   Big World Audio Theatre
# fetching   349:   Alabama
# fetching   350:   Klaas
# fetching   351:   Van Cliburn
# fetching   352:   James Blunt
# fetching   353:   The Naked And Famous
# fetching   354:   DJ RusLan
# fetching   355:   Steam Powered Giraffe
# fetching   356:   Oliver Moldan
# fetching   357:   Bag Raiders
# fetching   358:   Antoine Dufour
# fetching   359:   Karpe
# fetching   360:   Lazz
# fetching   361:   Vika Jigulina
# fetching   362:   John Debney, Alan Silvestri, Royal Scottish National Orchestra
# fetching   363:   Banana Airlines
# fetching   364:   Mandalay
# fetching   365:   Mini Mansions
# fetching   366:   CUTS
# fetching   367:   Teddy Wilson
# fetching   368:   The Click Five
# fetching   369:   Emily Bonabon
# fetching   370:   Sheryl Crow
# fetching   371:   Ingrid Olava
# fetching   372:   The Fratellis
# fetching   373:   Mogwai
# fetching   374:   The Weeknd
# fetching   375:   Gene Kelly
# fetching   376:   MAI LAN
# fetching   377:   Rivers Cuomo
# fetching   378:   Kate Miller-Heidke
# fetching   379:   Dolly Parton
# fetching   380:   Ólafur Arnalds
# fetching   381:   Hayley Kiyoko
# fetching   382:   Kanye West
# fetching   383:   Beyoncé
# fetching   384:   Dead Or Alive
# fetching   385:   Tomine Harket
# fetching   386:   Wang Chung
# fetching   387:   Jordan Perry
# fetching   388:   Tyler Childers
# fetching   389:   James Morrison
# fetching   390:   Rage Against The Machine
# fetching   391:   Mungo Jerry
# fetching   392:   3-11 Porter
# fetching   393:   Britten Quartet
# fetching   394:   Midnight Oil
# fetching   395:   Gente De Zona
# fetching   396:   The Righteous Brothers
# fetching   397:   Rag'n'Bone Man
# fetching   398:   Lil Tjay
# fetching   399:   Josh Groban
# fetching   400:   Zameer Rizvi
# fetching   401:   Daniele Luppi
# fetching   402:   Grand Funk Railroad
# fetching   403:   Naz Tokio
# fetching   404:   The Doors
# fetching   405:   Nature Sounds
# something went wrong
# fetching   406:   The Magnetic Fields
# fetching   407:   Fats Waller
# fetching   408:   Kundalini: Yoga, Meditation, Relaxation
# fetching   409:   Leonard Bernstein
# fetching   410:   Jordan Fisher
# fetching   411:   Kate Ryan
# fetching   412:   Norman Cook
# fetching   413:   The Wood Brothers
# fetching   414:   Drivvin
# fetching   415:   Dave Stewart
# fetching   416:   Freshlyground
# fetching   417:   Maddie & Tae
# fetching   418:   Conrad Sewell
# fetching   419:   Jessica Keenan Wynn
# fetching   420:   Alison Krauss
# fetching   421:   Kesha
# fetching   422:   Roy Purdy
# fetching   423:   Linus Young
# fetching   424:   Dennis Lloyd
# fetching   425:   Men Without Hats
# fetching   426:   Polina Gagarina
# fetching   427:   Childish Gambino
# fetching   428:   Jared Lee
# fetching   429:   DeJ Loaf
# fetching   430:   X Ambassadors
# fetching   431:   Alyssa Shouse
# fetching   432:   The Young Professionals
# fetching   433:   Dublication
# fetching   434:   David Bowie
# fetching   435:   Gary Pine
# fetching   436:   Easton Corbin
# fetching   437:   Faith No More
# fetching   438:   Todd Terje
# fetching   439:   LOONA
# fetching   440:   Jennifer Warnes
# fetching   441:   The B-52's
# fetching   442:   Lil Peep
# fetching   443:   Hollis
# fetching   444:   Kamelen
# fetching   445:   Clap Your Hands Say Yeah
# fetching   446:   Felicity
# fetching   447:   Ginuwine
# fetching   448:   Zacari
# fetching   449:   Spendtime Palace
# fetching   450:   Team Me
# fetching   451:   Sleepy Tom
# fetching   452:   Ben & Jason
# fetching   453:   Smash Mouth
# fetching   454:   Bea Miller
# fetching   455:   Bobby Darin
# fetching   456:   Cecil Taylor
# fetching   457:   Goldfrapp
# fetching   458:   The Middle East
# fetching   459:   J Balvin
# fetching   460:   Husbands
# fetching   461:   Everything But The Girl
# fetching   462:   Far East Movement
# fetching   463:   The Midnight
# fetching   464:   M'lynn
# fetching   465:   Echo & the Bunnymen
# fetching   466:   Pierce Brosnan
# fetching   467:   Pet Shop Boys
# fetching   468:   Delayde
# fetching   469:   White Hinterland
# fetching   470:   William Singe
# fetching   471:   Dillon
# fetching   472:   Page CXVI
# fetching   473:   Izabell
# fetching   474:   The Veronicas
# fetching   475:   Eddie Vedder
# fetching   476:   Dion
# fetching   477:   Emancipator
# fetching   478:   Roger Waters
# fetching   479:   Daryl Hall & John Oates
# fetching   480:   Redondo
# fetching   481:   Riton
# fetching   482:   Remy Ma
# fetching   483:   B.J. Thomas
# fetching   484:   Electus
# fetching   485:   Caleb and Kelsey
# fetching   486:   The Be Good Tanyas
# fetching   487:   Josh Dylan
# fetching   488:   UNKLE
# fetching   489:   The Mother Hips
# fetching   490:   Neneh Cherry
# fetching   491:   Sabi
# fetching   492:   Miscél
# fetching   493:   Sofía Reyes
# fetching   494:   Maino
# fetching   495:   Yael Naim
# fetching   496:   James Blake
# fetching   497:   T. Rex
# fetching   498:   Fleur East
# fetching   499:   Des'ree
# fetching   500:   Yves V
# fetching   501:   Akon
# fetching   502:   Tech N9ne Collabos
# fetching   503:   Danny Kaye
# fetching   504:   Emilie Brandt
# fetching   505:   Meghan Trainor
# fetching   506:   Ed Sheeran
# fetching   507:   Supermini
# fetching   508:   Limbo
# fetching   509:   Foreigner
# fetching   510:   Ben Folds Five
# fetching   511:   Radiohead
# fetching   512:   Man Without Country
# fetching   513:   Kirill Kondrashin
# fetching   514:   Greta Van Fleet
# fetching   515:   Eric Church
# fetching   516:   Simon Lunardi
# fetching   517:   Motörhead
# fetching   518:   Tiffany Alvord
# fetching   519:   Judas Priest
# fetching   520:   Kings of Nature
# fetching   521:   Hugh Jackman
# fetching   522:   Eagle-Eye Cherry
# fetching   523:   Smallpools
# fetching   524:   The Cat Empire
# fetching   525:   Cauterize
# fetching   526:   Burzum
# fetching   527:   Milo Greene
# fetching   528:   Machine Gun Kelly
# fetching   529:   Rob Viktum
# fetching   530:   Gillian Welch
# fetching   531:   Nina Simone
# fetching   532:   Hilltop Hoods
# fetching   533:   Glenn Lyse
# fetching   534:   Jarand
# fetching   535:   Daniel Pemberton
# fetching   536:   Jamie Topham
# fetching   537:   Natelad
# fetching   538:   Freddie Slack And His Orchestra
# fetching   539:   King Harvest
# fetching   540:   Federico Aubele
# fetching   541:   Diana Ross
# fetching   542:   Brandon Heath
# fetching   543:   The Getaway People
# fetching   544:   Jim Morrison
# fetching   545:   Skylar Grey
# fetching   546:   Jeremih
# fetching   547:   Nine Inch Nails
# fetching   548:   RAVVEL
# fetching   549:   Jewel
# fetching   550:   The Brook & The Bluff
# fetching   551:   Jamie Campbell Bower
# fetching   552:   Kenny Rogers
# fetching   553:   Away Team
# fetching   554:   Skye
# fetching   555:   Akula
# fetching   556:   Peter Sarstedt
# fetching   557:   The Trammps
# fetching   558:   Kelis
# fetching   559:   SEKAI NO OWARI
# fetching   560:   Natalie Imbruglia
# fetching   561:   Kylie Minogue
# fetching   562:   Sea Wolf
# fetching   563:   TØFL
# fetching   564:   PANG!
# fetching   565:   GameChops
# fetching   566:   Andrew Davis
# fetching   567:   Future Animals
# fetching   568:   Junip
# fetching   569:   Phil Wickham
# fetching   570:   Prince
# fetching   571:   Victoria Monét
# fetching   572:   Bhangralution
# fetching   573:   George Frideric Handel
# fetching   574:   Dan Tyminski
# fetching   575:   The Rolling Stones
# fetching   576:   Marble Sounds
# fetching   577:   Darren Styles
# fetching   578:   Deftones
# fetching   579:   John Neal
# fetching   580:   Nat & Alex Wolff
# fetching   581:   The Marvelettes
# fetching   582:   Katastrofe
# fetching   583:   Echosmith
# fetching   584:   KANT
# fetching   585:   Annika Wells
# fetching   586:   Grace Potter
# fetching   587:   Luca Schreiner
# fetching   588:   Charles Wright & The Watts 103rd Street Rhythm Band
# fetching   589:   Alan Menken
# fetching   590:   BIGBANG
# fetching   591:   Eric Hutchinson
# fetching   592:   M.I.A.
# fetching   593:   Goldfinger
# fetching   594:   Metallica
# fetching   595:   Bad Books
# fetching   596:   Dog's Eye View
# fetching   597:   Dimitri Vegas & Like Mike
# fetching   598:   Seal
# fetching   599:   Jonas Blue
# fetching   600:   Gregory and the Hawk
# fetching   601:   Peter Clemente
# fetching   602:   Fall Out Boy
# fetching   603:   Calum Scott
# fetching   604:   Au/Ra
# fetching   605:   Metric
# fetching   606:   Hayden Panettiere
# fetching   607:   Lars Vaular
# fetching   608:   Satin Jackets
# fetching   609:   Sofia Karlberg
# fetching   610:   Japan Ground Self Defense Force Central Band
# fetching   611:   Justin Roberts
# fetching   612:   Turnpike Troubadours
# fetching   613:   Atlas Genius
# fetching   614:   The Rembrandts
# fetching   615:   Maggie Lindemann
# fetching   616:   Sabrina Carpenter
# fetching   617:   Panama
# fetching   618:   HEDEGAARD
# fetching   619:   Behind Clouds
# fetching   620:   Alderliefste met Ramses Shaffy en Liesbeth List
# fetching   621:   Camila Cabello
# fetching   622:   Paramore
# fetching   623:   Project 46
# fetching   624:   The Cult
# fetching   625:   The Beach Boys
# fetching   626:   Swifty
# fetching   627:   Quinn XCII
# fetching   628:   Woodlock
# fetching   629:   Tame Impala
# fetching   630:   Elliott Smith
# fetching   631:   Snail's House
# fetching   632:   Shake Shake Go
# fetching   633:   Offentlig Sektor
# fetching   634:   Ascend The Hill
# fetching   635:   John Martin
# fetching   636:   Becky Hill
# fetching   637:   Ruel
# fetching   638:   CADE
# fetching   639:   Calle 13
# fetching   640:   Jessica Mauboy
# fetching   641:   The Sunday Drivers
# fetching   642:   Kenny Chesney
# fetching   643:   The Kills
# fetching   644:   Lily Allen
# fetching   645:   Édith Piaf
# fetching   646:   Gothenburg Symphony Orchestra
# fetching   647:   Zayion McCall
# fetching   648:   LÉON
# fetching   649:   Danny Ocean
# fetching   650:   Natasha Mosley
# fetching   651:   Toad The Wet Sprocket
# fetching   652:   BBC Philharmonic
# fetching   653:   Oasis
# fetching   654:   Martin Solveig
# fetching   655:   Alex Schulz
# fetching   656:   Vök
# fetching   657:   Sean Christopher
# fetching   658:   zalagasper
# fetching   659:   Crystal Castles
# fetching   660:   NONONO
# fetching   661:   The Cranberries
# fetching   662:   Lovey James
# fetching   663:   BBMAK
# fetching   664:   Hess Is More
# fetching   665:   Herman Düne
# fetching   666:   Wings
# fetching   667:   Kehlani
# fetching   668:   Joe Cocker
# fetching   669:   Benjamin Britten
# fetching   670:   Far Out
# fetching   671:   Avril Lavigne
# fetching   672:   MGMT
# fetching   673:   Phish
# fetching   674:   Kermit
# fetching   675:   Tristam
# fetching   676:   Adrian Von Ziegler
# fetching   677:   Injury Reserve
# fetching   678:   nobigdyl.
# fetching   679:   The Staves
# fetching   680:   Mammals
# fetching   681:   John Michael Montgomery
# fetching   682:   Alle Farben
# fetching   683:   Royal Philharmonic Orchestra
# fetching   684:   Air
# fetching   685:   Shinedown
# fetching   686:   RHODES
# fetching   687:   Hank Williams, Jr.
# fetching   688:   Kix Brooks
# fetching   689:   Marcy Playground
# fetching   690:   FITZ
# fetching   691:   Jens Book-Jenssen
# fetching   692:   Joaquín Sabina
# fetching   693:   Teemu
# fetching   694:   Johannes Brahms
# fetching   695:   Ephemerals
# fetching   696:   Duffy
# something went wrong
# fetching   697:   James Wolpert
# fetching   698:   Charlie Puth
# fetching   699:   Tez Cadey
# fetching   700:   Iron Butterfly
# fetching   701:   Savage Garden
# fetching   702:   Johann Sebastian Bach
# fetching   703:   Otis Taylor
# fetching   704:   Cheat Codes
# fetching   705:   Love and Theft
# fetching   706:   Miami DJ Collecetive
# fetching   707:   Jason Mraz
# fetching   708:   CL
# fetching   709:   LissA
# fetching   710:   The Pøssy Project
# fetching   711:   Proleter
# fetching   712:   Michela
# fetching   713:   Colin Firth
# fetching   714:   Foreign Air
# fetching   715:   Audio Bullys
# fetching   716:   Death From Above 1979
# fetching   717:   Tim Omaji
# fetching   718:   Busta Rhymes
# fetching   719:   Paul Simon
# fetching   720:   Brazilian Lounge Project
# fetching   721:   Fiorello
# fetching   722:   HAIM
# fetching   723:   Peter Dreimanis
# fetching   724:   Bryan White
# something went wrong
# fetching   725:   Linkin Park
# something went wrong
# fetching   726:   Debrah Scarlett
# fetching   727:   Shy Carter
# fetching   728:   FFS
# fetching   729:   CHUNG HA
# fetching   730:   Silentó
# fetching   731:   Splashh
# fetching   732:   Skunk Anansie
# fetching   733:   Foster The People
# fetching   734:   Sevenn
# fetching   735:   Berk & The Virtual Band
# fetching   736:   Grant Lee Buffalo
# fetching   737:   Dagny
# fetching   738:   Lifehouse
# fetching   739:   Audio Adrenaline
# fetching   740:   Score from the Motion Picture
# fetching   741:   TOTO
# fetching   742:   blackwave.
# fetching   743:   Rodríguez
# fetching   744:   Emilíana Torrini
# fetching   745:   NEIMY
# fetching   746:   Animotion
# fetching   747:   Darkthrone
# fetching   748:   Dr. Teeth and The Electric Mayhem
# fetching   749:   Tom Baker
# fetching   750:   Karen O
# fetching   751:   Glenn Miller
# fetching   752:   Marino Marini
# fetching   753:   Bobby Helms
# fetching   754:   Vince Guaraldi Trio
# fetching   755:   Huey Lewis & The News
# fetching   756:   The Raveonettes
# fetching   757:   Blitzkid
# fetching   758:   Call Me Loop
# fetching   759:   SoulCircuit
# fetching   760:   Van Morrison
# fetching   761:   Jeremy Camp
# fetching   762:   Punker
# fetching   763:   Band of Horses
# fetching   764:   Subtact
# fetching   765:   Claptone
# fetching   766:   Aimee Mann
# fetching   767:   Happyness
# fetching   768:   Starlive Café
# fetching   769:   Craft Spells
# fetching   770:   Roadtrip
# fetching   771:   The Animals
# fetching   772:   Christon Gray
# fetching   773:   The Turtles
# fetching   774:   Forteba
# fetching   775:   Ornette Coleman Trio
# fetching   776:   Parmalee
# fetching   777:   moow
# fetching   778:   Joywave
# fetching   779:   Tkay Maidza
# fetching   780:   Peter Wag
# fetching   781:   Hannah Fury
# fetching   782:   Logan Paul
# fetching   783:   Tears For Fears
# fetching   784:   Unwritten Law
# fetching   785:   Sammy Hagar
# fetching   786:   Kygo
# fetching   787:   Howard
# fetching   788:   Sophie Ellis-Bextor
# fetching   789:   The Amazing
# fetching   790:   American Federation of Musicians
# fetching   791:   Ryan Adams
# fetching   792:   Chicago Children's Choir
# fetching   793:   HALIENE
# fetching   794:   Sixpence None The Richer
# fetching   795:   Silk City
# fetching   796:   Conan Gray
# fetching   797:   Choir Of Young Believers
# fetching   798:   The Human League
# fetching   799:   Christopher Jackson
# fetching   800:   Carmody
# fetching   801:   L.V.
# fetching   802:   Mt. Eden
# fetching   803:   Yankie
# fetching   804:   Frank Zappa
# fetching   805:   Axwell /\ Ingrosso
# fetching   806:   Jay Electronica
# fetching   807:   Dustin Kensrue
# fetching   808:   Hootie & The Blowfish
# fetching   809:   ZZ Ward
# fetching   810:   Fugees
# fetching   811:   Kings of the River
# fetching   812:   Shakira
# fetching   813:   ✝✝✝ (Crosses)
# fetching   814:   Bombay Bicycle Club
# fetching   815:   Yo Gotti
# fetching   816:   Filter
# fetching   817:   Emapea
# fetching   818:   Jonas Aden
# fetching   819:   Bonnie Tyler
# fetching   820:   Destroyer
# fetching   821:   The Jackson 5
# fetching   822:   Baha Men
# fetching   823:   Hiatus Kaiyote
# fetching   824:   Eddy Arnold
# fetching   825:   Constantin
# fetching   826:   Soft Cell
# fetching   827:   Christian French
# fetching   828:   Nu Shooz
# fetching   829:   Kerli
# fetching   830:   Tibor Benyi
# fetching   831:   Sage The Gemini
# fetching   832:   First Aid Kit
# fetching   833:   Martha Wainwright
# fetching   834:   Raphael Saadiq
# fetching   835:   Keelan Donovan
# fetching   836:   The Oak Ridge Boys
# fetching   837:   Laurell
# fetching   838:   Lacrimosa
# fetching   839:   Johnny Nash
# fetching   840:   Shopan
# fetching   841:   Hugo Helmig
# fetching   842:   Tracy Chapman
# fetching   843:   Cody Johnson
# fetching   844:   Sex Pistols
# fetching   845:   Blue Öyster Cult
# fetching   846:   Tal Bachman
# fetching   847:   The Band CAMINO
# fetching   848:   Evangelos
# fetching   849:   Morgan Sulele
# fetching   850:   De-Phazz
# fetching   851:   Remo
# fetching   852:   Herbert von Karajan
# fetching   853:   Ásgeir
# fetching   854:   Collective Soul
# fetching   855:   Lexi
# fetching   856:   New Politics
# fetching   857:   4 Non Blondes
# fetching   858:   Jack White
# fetching   859:   Groove Armada
# fetching   860:   LMFAO
# fetching   861:   Lea Salonga
# fetching   862:   Jake Shimabukuro
# fetching   863:   Pro Sound Effects Library
# something went wrong
# fetching   864:   Carpenters
# fetching   865:   Chelsea Collins
# fetching   866:   Mørland
# fetching   867:   Vicetone
# fetching   868:   La Makina
# fetching   869:   Sara Bareilles
# fetching   870:   Yo La Tengo
# fetching   871:   Taylor Girlz
# fetching   872:   Reptar
# fetching   873:   GOAT
# fetching   874:   DJ Cassidy
# fetching   875:   Rachel Platten
# fetching   876:   Chris Tomlin
# fetching   877:   Quavo
# fetching   878:   Wheatus
# fetching   879:   Amber Run
# fetching   880:   Calboy
# fetching   881:   Watchhouse
# fetching   882:   Edie Brickell & New Bohemians
# fetching   883:   M83
# fetching   884:   White Noise Therapy
# something went wrong
# fetching   885:   Zyra
# fetching   886:   Taio Cruz
# fetching   887:   Kings of Leon
# fetching   888:   The Moleskins
# fetching   889:   Taylor Dayne
# fetching   890:   MOMOLAND
# fetching   891:   Robbie Seay Band
# fetching   892:   Astrid S
# fetching   893:   The Dresden Dolls
# fetching   894:   BRONCHO
# fetching   895:   Tobu
# fetching   896:   Diplo
# fetching   897:   MOTi
# fetching   898:   Madison Beer
# fetching   899:   The Black Atlantic
# fetching   900:   DiscoTech
# fetching   901:   Benjamin William Hastings
# fetching   902:   Lost Kings
# fetching   903:   josh pan
# fetching   904:   Laid Blak
# fetching   905:   Unwoman
# fetching   906:   Maroon 5
# fetching   907:   The Prodigy
# fetching   908:   BTS
# fetching   909:   The Vamps
# fetching   910:   Rowlf
# fetching   911:   Gym Class Heroes
# fetching   912:   Leland
# fetching   913:   Futuristic Polar Bears
# fetching   914:   Kiiara
# fetching   915:   Rob Vicious
# fetching   916:   Rhoda
# fetching   917:   Morcheeba
# fetching   918:   009 Sound System
# fetching   919:   Kid Ink
# fetching   920:   Etta James
# fetching   921:   Bryson Tiller
# fetching   922:   Rennie!
# fetching   923:   Veela
# fetching   924:   Kaskade
# fetching   925:   Iffy Orbit
# fetching   926:   Roy Orbison
# fetching   927:   Tennyson
# fetching   928:   Adam Doleac
# fetching   929:   Kero One
# fetching   930:   Beirut
# fetching   931:   Elly Ekko
# fetching   932:   The Short Straws
# fetching   933:   Meat Beat Manifesto
# fetching   934:   Bryden Thomson
# fetching   935:   Supertramp
# fetching   936:   Ashe
# fetching   937:   Colton Dixon
# fetching   938:   Revolver
# fetching   939:   Moto Boy
# fetching   940:   Mitchell Ayres & His Orchestra
# fetching   941:   Black Box Recorder
# fetching   942:   Herbie Hancock
# fetching   943:   Evan Gartner
# fetching   944:   Parson James
# fetching   945:   Sojourn
# fetching   946:   Phil Harris
# fetching   947:   SUNMI
# fetching   948:   Echos
# fetching   949:   Ying Yang Twins
# fetching   950:   Cigarettes After Sex
# fetching   951:   Brika
# fetching   952:   Stray Kids
# fetching   953:   Cœur De Pirate
# fetching   954:   Amy Macdonald
# fetching   955:   Cole Porter
# fetching   956:   Abbey Road
# fetching   957:   Tham Sway
# fetching   958:   Wild Party
# fetching   959:   Hayley Warner
# fetching   960:   Jason Mraz & Colbie Caillat
# fetching   961:   Seven Bucks
# fetching   962:   Mary Elizabeth McGlynn
# fetching   963:   Disciples
# fetching   964:   Starley
# fetching   965:   Lenny Kravitz
# fetching   966:   Hooray For Earth
# fetching   967:   Gnarls Barkley
# fetching   968:   Ryan Davies
# fetching   969:   Brenda Lee
# fetching   970:   Cam
# fetching   971:   ABBA
# fetching   972:   Hanzee
# fetching   973:   Kendrick Lamar
# fetching   974:   The Hooters
# fetching   975:   J. Dash
# fetching   976:   RAYE
# fetching   977:   Sam Palladio
# fetching   978:   PLVTINUM
# fetching   979:   A.R. Rahman
# fetching   980:   The Marshall Tucker Band
# fetching   981:   Trapt
# something went wrong
# fetching   982:   Original Broadway Cast of Hamilton
# fetching   983:   I Monster
# fetching   984:   Kajander
# fetching   985:   DevilDriver
# fetching   986:   Lionel Richie
# fetching   987:   Gerard McMann
# fetching   988:   Blindside
# fetching   989:   Swervedriver
# fetching   990:   Sharpay Evans
# fetching   991:   John Ryan
# fetching   992:   Billy Ocean
# fetching   993:   De La Ghetto
# fetching   994:   Terry Jacks
# fetching   995:   Beowülf
# fetching   996:   Ramz
# fetching   997:   A L E X
# fetching   998:   Max Frost
# fetching   999:   Mungo's Hi Fi
# fetching  1000:   Bolier
# fetching  1001:   Kajagoogoo
# fetching  1002:   Oskar Flood
# fetching  1003:   Francesca Battistelli
# fetching  1004:   The Fjords
# fetching  1005:   Sebastian Perez
# fetching  1006:   Party Pupils
# fetching  1007:   RykkinnFella
# fetching  1008:   Tim Schou
# fetching  1009:   Foo Fighters
# fetching  1010:   Ballyhoo!
# fetching  1011:   Ojivolta
# fetching  1012:   Henrik Wiese
# fetching  1013:   Romy
# fetching  1014:   The Pussycat Dolls
# fetching  1015:   Real Life
# fetching  1016:   Tommy James & The Shondells
# fetching  1017:   Kelly Clarkson
# fetching  1018:   Manchester Orchestra
# fetching  1019:   Oleander
# fetching  1020:   Sarah Bonito
# fetching  1021:   Bobby McFerrin
# fetching  1022:   Kay Cook
# fetching  1023:   Cults
# fetching  1024:   Placebo
# something went wrong
# fetching  1025:   Molly Johnson
# fetching  1026:   Oliver Heldens
# fetching  1027:   Kim Cesarion
# fetching  1028:   Lucenzo
# fetching  1029:   Nelly Furtado
# fetching  1030:   Gabrielle
# fetching  1031:   James
# fetching  1032:   Machine Head
# fetching  1033:   Robin Smith
# fetching  1034:   Jay Park
# fetching  1035:   Modest Mouse
# fetching  1036:   Tracy Byrd
# fetching  1037:   Rita Ora
# fetching  1038:   Ilsey
# fetching  1039:   DJ Katch
# fetching  1040:   Artur Rodzinski
# fetching  1041:   Regina Spektor
# fetching  1042:   Animal Collective
# fetching  1043:   Billie Holiday
# fetching  1044:   Rilo Kiley
# fetching  1045:   Gary Numan
# fetching  1046:   Donny Osmond
# fetching  1047:   SZA
# fetching  1048:   Black Eyed Peas
# fetching  1049:   Cher
# fetching  1050:   Chen Reiss
# fetching  1051:   Antony and the Johnsons
# fetching  1052:   EXO
# fetching  1053:   Alan Walker
# fetching  1054:   City Spud
# fetching  1055:   Robbie Williams
# fetching  1056:   The War On Drugs
# fetching  1057:   Black Marble
# fetching  1058:   Tom Tykwer
# fetching  1059:   Riah
# fetching  1060:   NOTD
# fetching  1061:   The Submarines
# fetching  1062:   Adrian Lux
# fetching  1063:   Wynter Gordon
# fetching  1064:   Charles Trenet
# fetching  1065:   Nine Lashes
# fetching  1066:   fun.
# fetching  1067:   Pearl Jam
# fetching  1068:   After The Fire
# fetching  1069:   DARKSIDE
# fetching  1070:   Marius Furche
# fetching  1071:   Chase Atlantic
# fetching  1072:   Illy
# fetching  1073:   Refuzion
# fetching  1074:   Bob Marley & The Wailers
# fetching  1075:   Freya Ridings
# fetching  1076:   Faces
# fetching  1077:   Marko Penn
# fetching  1078:   The Psychedelic Furs
# fetching  1079:   Tove Styrke
# fetching  1080:   dvsn
# fetching  1081:   Alderliefste
# fetching  1082:   Hope Sandoval & The Warm Inventions
# fetching  1083:   Simon Van Holen
# fetching  1084:   The Stooges
# fetching  1085:   Kierra Sheard
# fetching  1086:   ARTY
# fetching  1087:   CocoRosie
# fetching  1088:   Mat Kearney
# fetching  1089:   Rob Thomas
# fetching  1090:   KAINA
# fetching  1091:   Hermitude
# fetching  1092:   Danger Mouse
# fetching  1093:   JENNIE
# fetching  1094:   KALEO
# fetching  1095:   ZAYN
# fetching  1096:   John Coltrane
# fetching  1097:   Weather Report
# fetching  1098:   CID
# fetching  1099:   Shigeru Umebayashi
# fetching  1100:   Moby
# fetching  1101:   Lyricist
# fetching  1102:   The Meters
# fetching  1103:   The Boo Radleys
# fetching  1104:   Bon Jovi
# fetching  1105:   LEN
# fetching  1106:   Tommy Tutone
# fetching  1107:   Jacquees
# fetching  1108:   Stonefox
# fetching  1109:   Nicole Scherzinger
# fetching  1110:   JHart
# fetching  1111:   Kat Nestel
# fetching  1112:   Tai
# fetching  1113:   Dumdum Boys
# fetching  1114:   The Velvet Underground
# fetching  1115:   Peter Frampton
# fetching  1116:   Lil Kleine
# fetching  1117:   Eva Weel Skram
# fetching  1118:   Charlie Who?
# fetching  1119:   The Fall of Troy
# fetching  1120:   Timbuktu
# fetching  1121:   Batushka
# fetching  1122:   R.E.M.
# fetching  1123:   The Troggs
# fetching  1124:   Lorne Balfe
# fetching  1125:   Albert Hammond Jr
# fetching  1126:   Fjord
# fetching  1127:   The Handsome Family
# fetching  1128:   Jessica Rothe
# fetching  1129:   Jack & Jack
# fetching  1130:   Billy Idol
# fetching  1131:   Toploader
# fetching  1132:   Guy
# fetching  1133:   Astronauts
# fetching  1134:   Flo Rida
# fetching  1135:   Maisie Peters
# fetching  1136:   Frank Løke
# fetching  1137:   Fernando Tessis
# fetching  1138:   Soundgarden
# fetching  1139:   Mirelys Morgan Verdecia
# fetching  1140:   Leon Bridges
# fetching  1141:   Little Big Town
# fetching  1142:   Marilyn Manson
# fetching  1143:   Fuel
# fetching  1144:   Ansel Elgort
# fetching  1145:   Clutch
# fetching  1146:   Gardiner Sisters
# fetching  1147:   Harry "Sweets" Edison
# fetching  1148:   112
# fetching  1149:   David Ngyah
# fetching  1150:   Moca
# fetching  1151:   Israel Kamakawiwo'ole
# fetching  1152:   Passion Pit
# fetching  1153:   Padma Purana
# fetching  1154:   Teleman
# fetching  1155:   Slowdive
# fetching  1156:   Howard Shelley
# fetching  1157:   Audien
# fetching  1158:   Arnór Dan
# fetching  1159:   Jimmy Eat World
# fetching  1160:   Trent Tomlinson
# fetching  1161:   Dermot Kennedy
# fetching  1162:   Skott
# fetching  1163:   Matt Redman
# fetching  1164:   Ellusive
# fetching  1165:   Ibeyi
# fetching  1166:   Chris Stapleton
# fetching  1167:   Panos Mouzourakis
# fetching  1168:   Dio
# fetching  1169:   Blue Swede
# fetching  1170:   Alan Jackson
# fetching  1171:   Gregory Porter
# fetching  1172:   Grace VanderWaal
# fetching  1173:   Summer Heart
# fetching  1174:   Queen Pen
# fetching  1175:   Janove
# fetching  1176:   Gabriella
# fetching  1177:   scntfc
# fetching  1178:   Active Child
# fetching  1179:   Sarah Vaughan
# fetching  1180:   Bebe Rexha
# fetching  1181:   Maia Wright
# fetching  1182:   Plumb
# fetching  1183:   The Story So Far
# fetching  1184:   John Legend
# fetching  1185:   The Praise Baby Collection
# fetching  1186:   The Rock Masters
# fetching  1187:   Saudi
# fetching  1188:   Can't Stop Won't Stop
# fetching  1189:   Eartha Kitt
# fetching  1190:   Lady A
# fetching  1191:   Fiona Apple
# fetching  1192:   Rob Swire
# fetching  1193:   Bearson
# fetching  1194:   Jennifer Lopez
# fetching  1195:   Toby Keith
# fetching  1196:   Fleet Foxes
# fetching  1197:   Lisa Hannigan
# fetching  1198:   Deep Purple
# fetching  1199:   Christopher
# fetching  1200:   Yugen Blakrok
# fetching  1201:   Knox Hamilton
# fetching  1202:   Train
# fetching  1203:   Scott McKenzie
# fetching  1204:   Dave Brubeck
# fetching  1205:   Evile
# fetching  1206:   Ja Rule
# fetching  1207:   Rednex
# fetching  1208:   Chick Webb
# fetching  1209:   Meek Mill
# fetching  1210:   Zach Williams
# fetching  1211:   Big Freedia
# fetching  1212:   Building 429
# fetching  1213:   U.K. Mix Masters
# fetching  1214:   Céline Dion
# fetching  1215:   Mark Wills
# fetching  1216:   Gorillaz
# fetching  1217:   Adriano Celentano
# fetching  1218:   Maren Morris
# fetching  1219:   James Hype
# fetching  1220:   Eiffel 65
# fetching  1221:   John Martyn
# fetching  1222:   The Band
# fetching  1223:   TEMPOREX
# fetching  1224:   Modulation
# fetching  1225:   Youssou N'Dour
# fetching  1226:   Dillon Francis
# fetching  1227:   Athlete
# fetching  1228:   The Lumineers
# fetching  1229:   Two Door Cinema Club
# fetching  1230:   Haley Flake
# fetching  1231:   Mike Perry
# fetching  1232:   Was (Not Was)
# fetching  1233:   Brendan James
# fetching  1234:   Jay Rock
# fetching  1235:   Jane's Addiction
# fetching  1236:   Louis The Child
# fetching  1237:   BEK & Wallin
# fetching  1238:   Kurt Nilsen
# fetching  1239:   Eagles Of Death Metal
# fetching  1240:   Stonebank
# fetching  1241:   CODE KUNST
# fetching  1242:   Justin Timberlake
# fetching  1243:   Michael Jackson
# fetching  1244:   DEAMN
# fetching  1245:   Penny and Sparrow
# fetching  1246:   System Of A Down
# fetching  1247:   Will Smith
# fetching  1248:   Louis Futon
# fetching  1249:   Gavin Greenaway
# fetching  1250:   Nickelback
# fetching  1251:   kent
# fetching  1252:   Lil Jon
# fetching  1253:   Andra Day
# fetching  1254:   William Fitzsimmons
# fetching  1255:   Dylan Scott
# fetching  1256:   Kavinsky
# fetching  1257:   Lindsey Stirling
# fetching  1258:   Delara
# fetching  1259:   Boris Bloch
# fetching  1260:   B. Lamar
# fetching  1261:   Cage The Elephant
# fetching  1262:   Anna of the North
# fetching  1263:   MATTN
# fetching  1264:   Crash Test Dummies
# fetching  1265:   Rick James
# fetching  1266:   Fuse ODG
# fetching  1267:   Nyxen
# fetching  1268:   Descemer Bueno
# fetching  1269:   Jack Dee
# fetching  1270:   Lazyboy
# fetching  1271:   Naughty Boy
# fetching  1272:   Matt Bloyd
# fetching  1273:   Hillsong UNITED
# fetching  1274:   Daler Mehndi
# fetching  1275:   Peter von Poehl
# fetching  1276:   Carly Pearce
# fetching  1277:   S U R V I V E
# fetching  1278:   Procol Harum
# fetching  1279:   Bruno Mars
# fetching  1280:   How To Destroy Angels
# fetching  1281:   Lilac
# fetching  1282:   MickeyG
# fetching  1283:   Groovefinder
# fetching  1284:   Mikky Ekko
# fetching  1285:   Sleigh Bells
# fetching  1286:   Richard O'Brien
# fetching  1287:   SAFIA
# fetching  1288:   Empress Of
# fetching  1289:   The Verve Pipe
# fetching  1290:   Philipp Beesen
# fetching  1291:   CHAMPS
# fetching  1292:   Ratatat
# fetching  1293:   Sebastian Kamae
# fetching  1294:   Jerry Paper
# fetching  1295:   Mark Ronson
# fetching  1296:   VNV Nation
# fetching  1297:   To Kill A King
# fetching  1298:   Global Communication
# fetching  1299:   Jake Owen
# fetching  1300:   Ava Max
# fetching  1301:   Silverchair
# fetching  1302:   Damn Yankees
# fetching  1303:   Helena Bonham Carter
# fetching  1304:   In Flames
# fetching  1305:   Why Don't We
# fetching  1306:   La La Land Cast
# fetching  1307:   Sublime
# fetching  1308:   Wilson Pickett
# fetching  1309:   Shoreline Mafia
# fetching  1310:   Stevie Wonder
# fetching  1311:   The Black Keys
# fetching  1312:   Led Zeppelin
# fetching  1313:   Fresh Big Mouf
# fetching  1314:   Rock Mafia
# fetching  1315:   Jack Joseph Puig
# fetching  1316:   Bluecoats Drum and Bugle Corp
# fetching  1317:   John Mayer
# fetching  1318:   Henry Mancini
# fetching  1319:   Hot Chocolate
# fetching  1320:   Pigeon John
# fetching  1321:   Amos Lee
# fetching  1322:   Görkem Han
# fetching  1323:   Alabama 3
# fetching  1324:   Madonna
# fetching  1325:   The Head And The Heart
# fetching  1326:   Juan Magán
# fetching  1327:   Village People
# fetching  1328:   Danelle Sandoval
# fetching  1329:   Frankie Valli & The Four Seasons
# fetching  1330:   Hollow Light
# fetching  1331:   OHGEESY
# fetching  1332:   Smoma
# fetching  1333:   Bert Jansch
# fetching  1334:   Madeon
# fetching  1335:   Willie Nelson
# fetching  1336:   Johnny Klimek
# fetching  1337:   Lush & Simon
# fetching  1338:   Eddie Meduza
# fetching  1339:   Earl Sweatshirt
# fetching  1340:   Trey Songz
# fetching  1341:   Johann Nepomuk Hummel
# fetching  1342:   Elina
# fetching  1343:   Coldplay
# fetching  1344:   The Hives
# fetching  1345:   Fake Feathers
# fetching  1346:   George Michael
# fetching  1347:   Zo
# fetching  1348:   MF Grimm
# fetching  1349:   Heartless Bastards
# fetching  1350:   Judah & the Lion
# fetching  1351:   Taron Egerton
# fetching  1352:   Rubik
# fetching  1353:   Austin Burke
# fetching  1354:   Black Label Society
# fetching  1355:   Joanna Jones
# fetching  1356:   Akeron
# fetching  1357:   Clem Leek
# fetching  1358:   King Crimson
# fetching  1359:   Another One Back
# fetching  1360:   Roman GianArthur
# fetching  1361:   Barcelona
# fetching  1362:   Baddiel, Skinner & Lightning Seeds
# fetching  1363:   Jay Cooper
# fetching  1364:   Johnnie Taylor
# fetching  1365:   Sneaky
# fetching  1366:   5 Seconds of Summer
# fetching  1367:   Indelible Grace Music
# fetching  1368:   Campsite Dream
# fetching  1369:   Ryan Bingham
# fetching  1370:   Shawn Colvin
# fetching  1371:   Years & Years
# fetching  1372:   Rich Homie Quan
# fetching  1373:   Vampire Weekend
# fetching  1374:   Postgirobygget
# fetching  1375:   Def Leppard
# fetching  1376:   FLORiS
# fetching  1377:   Pharrell Williams
# fetching  1378:   Ben E. King
# fetching  1379:   S3RL
# fetching  1380:   S-Tone Inc
# fetching  1381:   Jonathan Jeremiah
# fetching  1382:   Shesso
# fetching  1383:   The Killers
# fetching  1384:   The Proclaimers
# fetching  1385:   Lil Uzi Vert
# fetching  1386:   The Doobie Brothers
# fetching  1387:   AGM
# fetching  1388:   Lebo M.
# fetching  1389:   KREAM
# fetching  1390:   K&D ft Mahoney
# fetching  1391:   Adel
# fetching  1392:   New Radicals
# fetching  1393:   T-ARA
# fetching  1394:   Helena Noguerra
# fetching  1395:   A R I Z O N A
# fetching  1396:   Assassin's Creed
# fetching  1397:   The Jepettos
# fetching  1398:   Cartoon
# fetching  1399:   Nico & Vinz
# fetching  1400:   Kill Hannah
# fetching  1401:   Jack's Mannequin
# fetching  1402:   Vanilla Ice
# fetching  1403:   AHS Project
# fetching  1404:   YG
# fetching  1405:   'Til Tuesday
# fetching  1406:   Kate Havnevik
# fetching  1407:   High School Musical Cast
# fetching  1408:   Trace Adkins
# fetching  1409:   CeeLo Green
# fetching  1410:   The Chemical Brothers
# fetching  1411:   Mabel
# fetching  1412:   Robert Smith
# fetching  1413:   Yxng Bane
# fetching  1414:   Ronny Jordan
# fetching  1415:   Alicks
# fetching  1416:   Brynn Elliott
# fetching  1417:   The Downtown Fiction
# fetching  1418:   Ra Ra Riot
# fetching  1419:   Danny Pratt
# fetching  1420:   Sigma
# fetching  1421:   Alanis Morissette
# fetching  1422:   Jade Bird
# fetching  1423:   Big Data
# fetching  1424:   Future
# fetching  1425:   Zap Mama
# fetching  1426:   JGivens
# fetching  1427:   Tegan and Sara
# fetching  1428:   Frankie Goes To Hollywood
# fetching  1429:   Roger Bart
# fetching  1430:   Grizzly Bear
# fetching  1431:   s. lyre
# fetching  1432:   Jorja Smith
# something went wrong
# fetching  1433:   Maverick Sabre
# fetching  1434:   VINAI
# fetching  1435:   Mustard
# fetching  1436:   The Academy Orchestra
# fetching  1437:   Gravenhurst
# fetching  1438:   Vertical Horizon
# fetching  1439:   Huncho Jack
# fetching  1440:   Jamelia
# fetching  1441:   Whethan
# fetching  1442:   NoMBe
# fetching  1443:   Dario G & Mark Tucker
# fetching  1444:   ATEEZ
# fetching  1445:   FRENSHIP
# fetching  1446:   Austin Mahone
# fetching  1447:   Donald O'Connor
# fetching  1448:   SNSD
# fetching  1449:   Daniel Powter
# fetching  1450:   The Score
# something went wrong
# fetching  1451:   BROODS
# fetching  1452:   Ween
# fetching  1453:   Northmane
# fetching  1454:   Justin Hurwitz
# fetching  1455:   Sir Sly
# fetching  1456:   Eagles
# fetching  1457:   Team 10
# fetching  1458:   The Jordanaires
# fetching  1459:   Betty Who
# fetching  1460:   Oral Bee
# fetching  1461:   Thriving Ivory
# fetching  1462:   Endemix
# fetching  1463:   Thompson Square
# fetching  1464:   The Fray
# fetching  1465:   Frances
# fetching  1466:   Deep Blue Something
# fetching  1467:   ODESZA
# fetching  1468:   Ronnie Dunn
# fetching  1469:   Kenny G
# fetching  1470:   ALMA
# fetching  1471:   RAC
# fetching  1472:   Dream Theater
# fetching  1473:   MORTEN
# fetching  1474:   REO Speedwagon
# fetching  1475:   RY X
# fetching  1476:   Steve Winwood
# fetching  1477:   Crowded House
# fetching  1478:   Craig Ferguson
# fetching  1479:   Sonny & Cher
# fetching  1480:   Dresses
# fetching  1481:   Cats On Trees
# fetching  1482:   Rachel House
# fetching  1483:   Stefflon Don
# fetching  1484:   The Zombies
# fetching  1485:   Galimatias
# fetching  1486:   DVNO
# fetching  1487:   Pete Anthony
# fetching  1488:   Neku
# fetching  1489:   Electric Six
# fetching  1490:   Skeeter Davis
# fetching  1491:   Dysplay
# fetching  1492:   Maribelle
# fetching  1493:   John Adams
# fetching  1494:   Working for a Nuclear Free City
# fetching  1495:   Zac Efron
# fetching  1496:   Yazoo
# fetching  1497:   Dido
# fetching  1498:   Porno for Pyros
# fetching  1499:   Aerosmith
# fetching  1500:   Brendon Urie
# fetching  1501:   kenzie
# fetching  1502:   Sean Beavan
# fetching  1503:   Nelson May
# fetching  1504:   Troye Sivan
# fetching  1505:   HRVY
# fetching  1506:   Lou Rawls
# fetching  1507:   Vince Staples
# fetching  1508:   Average White Band
# fetching  1509:   Dirty Heads
# fetching  1510:   Mataya
# fetching  1511:   Selena Gomez & The Scene
# fetching  1512:   Foxygen
# fetching  1513:   Sonn
# fetching  1514:   Lucky Luciano
# fetching  1515:   Fozzie
# fetching  1516:   Antonín Dvořák
# fetching  1517:   Mel Ashton
# fetching  1518:   Carrie Underwood
# fetching  1519:   Connie Britton
# fetching  1520:   David Guetta
# fetching  1521:   Odessa
# fetching  1522:   iamjakehill
# fetching  1523:   Trevor Guthrie
# fetching  1524:   MKTO
# fetching  1525:   Front 242
# fetching  1526:   RSP & Thomax
# fetching  1527:   Mocki
# fetching  1528:   Rufus Wainwright
# fetching  1529:   Cat Power
# fetching  1530:   Cynthia Harrell
# fetching  1531:   Van Halen
# fetching  1532:   Great Lake Swimmers
# fetching  1533:   Donkeyboy
# fetching  1534:   The Five Stairsteps
# fetching  1535:   TOMORROW X TOGETHER
# fetching  1536:   RL Grime
# fetching  1537:   YUNGBLUD
# fetching  1538:   Selah
# fetching  1539:   Roy Blair
# fetching  1540:   Beatsteaks
# fetching  1541:   Peaches
# fetching  1542:   Mackintosh Braun
# fetching  1543:   Paolo Nutini
# fetching  1544:   Cher Lloyd
# fetching  1545:   Rob Dougan
# fetching  1546:   Mr. C
# fetching  1547:   Junkie XL
# fetching  1548:   ItaloBrothers
# fetching  1549:   Nick Drake
# fetching  1550:   Erika Costell
# fetching  1551:   Fools Garden
# fetching  1552:   Animal Alpha
# fetching  1553:   Lulleaux
# fetching  1554:   Bright Sparks
# fetching  1555:   Pentatonix
# fetching  1556:   The Bangles
# fetching  1557:   Kah-Lo
# fetching  1558:   Midland
# fetching  1559:   Alexandre Desplat
# fetching  1560:   KVR
# fetching  1561:   James Brown
# ...
# fetching  3882:   Michael Bublé
# fetching  3883:   The Strokes
# fetching  3884:   Incubus
# fetching  3885:   Tom Lord-Alge
# fetching  3886:   Flyleaf
# fetching  3887:   Dan + Shay
# fetching  3888:   James Newton Howard
# fetching  3889:   Smokie
# fetching  3890:   Jakubi
# fetching  3891:   The Tokens
# fetching  3892:   Felix Jaehn
# fetching  3893:   Entombed
# fetching  3894:   Jacob Sartorius
# fetching  3895:   Faul & Wad
# fetching  3896:   John Williams
# fetching  3897:   Purity Ring
# fetching  3898:   Editors
# fetching  3899:   Streetlight Manifesto
# fetching  3900:   Quiz Worx
# fetching  3901:   Steve Tannen
# fetching  3902:   New York Philharmonic
# fetching  3903:   Ukulele Clan Band
# fetching  3904:   Dan Stevens
# fetching  3905:   NEFFEX
# fetching  3906:   Vinyl Hearts
# fetching  3907:   Charlotte Lawrence
# fetching  3908:   The Osborne Brothers
# fetching  3909:   4Minute
# fetching  3910:   Max Jury
# fetching  3911:   Nelly
# fetching  3912:   Blak
# fetching  3913:   El Cata
# fetching  3914:   Chevrae
# fetching  3915:   Tony Bennett
# fetching  3916:   Olivia O'Brien
# fetching  3917:   Becky G
# fetching  3918:   Waylon Jennings
# fetching  3919:   Terence Klein
# fetching  3920:   Spin Doctors
# fetching  3921:   Randy Travis
# fetching  3922:   Crowder
# fetching  3923:   Blinky Blink
# fetching  3924:   Ennio Morricone
# fetching  3925:   Chet Faker
# fetching  3926:   Luxury Grooves
# fetching  3927:   Loreena McKennitt
# fetching  3928:   Brad Garrett
# fetching  3929:   Johan Dresser
# fetching  3930:   Cupid
# fetching  3931:   TOOMANYLEFTHANDS
# fetching  3932:   Black Daniel
# fetching  3933:   Ashleigh Murray
# fetching  3934:   Damien Jurado
# fetching  3935:   Björk
# fetching  3936:   Jeff Buckley
# fetching  3937:   Chase Rice
# fetching  3938:   Matt Maeson
# fetching  3939:   James Yorkston
# fetching  3940:   Shawn Mullins
# fetching  3941:   65daysofstatic
# fetching  3942:   Lookas
# fetching  3943:   LP
# fetching  3944:   LOONA/yyxy
# fetching  3945:   Pixies
# fetching  3946:   Arctic Monkeys
# fetching  3947:   Cezinando
# fetching  3948:   LCD Soundsystem
# fetching  3949:   LunchMoney Lewis
# fetching  3950:   The Very Best
# fetching  3951:   Moloko
# fetching  3952:   Cody Purvis
# fetching  3953:   Noah Kahan
# fetching  3954:   Mattybraps
# fetching  3955:   Everything Everything
# fetching  3956:   Saint Motel
# fetching  3957:   Karen Gibson Roc
# fetching  3958:   gugudan
# fetching  3959:   Third Eye Blind
# fetching  3960:   Danielle Haim
# fetching  3961:   Bad Meets Evil
# fetching  3962:   Boston Bun
# fetching  3963:   Cantoma
# fetching  3964:   Street Corner Symphony
# fetching  3965:   Bloodhound Gang
# fetching  3966:   Dr. John
# fetching  3967:   Patrice Rushen
# fetching  3968:   James Horner
# fetching  3969:   Chris Crone
# fetching  3970:   Nathan Lane
# fetching  3971:   Macross 82-99
# fetching  3972:   Jimilian
# fetching  3973:   MAGIC GIANT
# fetching  3974:   Poe
# fetching  3975:   The Presidents Of The United States Of America
# fetching  3976:   Lennon Stella
# fetching  3977:   Sleepy Brown
# fetching  3978:   Jon Crusoe
# fetching  3979:   Dawa
# fetching  3980:   Bishop Briggs
# fetching  3981:   CIRE
# fetching  3982:   Iyaz
# fetching  3983:   Creed
# fetching  3984:   Garot Michael Conklin
# fetching  3985:   Mike Eli
# fetching  3986:   Twin Caverns
# fetching  3987:   Phoebe Killdeer
# fetching  3988:   The Clash
# fetching  3989:   Just A Gent
# fetching  3990:   Marc E. Bassy
# fetching  3991:   My Epic
# fetching  3992:   Mitchell Tenpenny
# fetching  3993:   Tarro
# something went wrong
# fetching  3994:   Jason Isbell and the 400 Unit
# fetching  3995:   Brandon Lay
# fetching  3996:   Levi Hummon
# fetching  3997:   Tracy Lawrence
# fetching  3998:   Baths
# fetching  3999:   Ruff Loaderz
# fetching  4000:   Logic
# fetching  4001:   Talib Kweli
# fetching  4002:   fantompower
# fetching  4003:   Gerard Butler
# fetching  4004:   Joakim Molitor
# fetching  4005:   Brand New
# fetching  4006:   Kelsea Ballerini
# fetching  4007:   Bear's Den
# fetching  4008:   Mazzy Star
# fetching  4009:   The Weather Girls
# fetching  4010:   Coolio
# fetching  4011:   George R. R. Martin
# fetching  4012:   TLC
# fetching  4013:   Alex & Sierra
# fetching  4014:   Diamond Rio
# fetching  4015:   Dierks Bentley
# fetching  4016:   Katy Perry
# fetching  4017:   Jerry Orbach
# fetching  4018:   David Cook
# fetching  4019:   Zwette
# fetching  4020:   Skywalker Symphony Orchestra
# fetching  4021:   RM
# fetching  4022:   Teddybears
# fetching  4023:   The Civil Wars
# fetching  4024:   The Easybeats
# fetching  4025:   Amy Adams
# fetching  4026:   Ylvis
# fetching  4027:   Frøder
# fetching  4028:   Matchbox Twenty
# fetching  4029:   Carlos y Alejandra
# fetching  4030:   Creedence Clearwater Revival
# fetching  4031:   The Districts
# fetching  4032:   Andrew McMahon in the Wilderness
# fetching  4033:   B. More
# fetching  4034:   Panda Bear
# fetching  4035:   Grouplove
# fetching  4036:   blink-182
# fetching  4037:   Louis Jordan & His Tympany Five
# fetching  4038:   Matstubs
# fetching  4039:   Kody Ryan
# fetching  4040:   Phantasialand
# fetching  4041:   Hacienda
# fetching  4042:   Wynonie Harris
# fetching  4043:   Soft Machine
# fetching  4044:   Ella Fitzgerald
# fetching  4045:   Alexi Blue
# fetching  4046:   Xavier Mayne
# fetching  4047:   Bryan Ferry
# fetching  4048:   Rik Rok
# fetching  4049:   Charlie Brown
# fetching  4050:   Grey Holiday
# fetching  4051:   Steely Dan
# fetching  4052:   KJ Apa
# fetching  4053:   Harald Kloser
# fetching  4054:   Crystal Lake
# fetching  4055:   Static Major
# fetching  4056:   Jason Derulo
# fetching  4057:   Washed Out
# fetching  4058:   Janelle Monáe
# fetching  4059:   Tindersticks
# fetching  4060:   Elliphant
# fetching  4061:   Night Moves
# fetching  4062:   寺島尚彦
# fetching  4063:   Rhett Walker
# fetching  4064:   Iván Torrent
# fetching  4065:   Diddy - Dirty Money
# fetching  4066:   Playboi Carti
# fetching  4067:   WHTKD
# fetching  4068:   Leska
# fetching  4069:   Troy
# fetching  4070:   Christopher Norman
# fetching  4071:   GRADES
# fetching  4072:   David Archuleta
# fetching  4073:   Los Campesinos!
# fetching  4074:   Max Cooper
# fetching  4075:   Tina Charles
# fetching  4076:   RUNN
# fetching  4077:   Billy Magnussen
# fetching  4078:   KYLE
# fetching  4079:   Justine Skye
# fetching  4080:   Our Lady Peace
# fetching  4081:   Tee Grizzley
# fetching  4082:   The Isley Brothers
# fetching  4083:   Clairy Browne & The Bangin' Rackettes
# fetching  4084:   Ole Ivars
# fetching  4085:   The Leisure Society
# fetching  4086:   White Sea
# something went wrong
# fetching  4087:   Landon Pigg
# fetching  4088:   KIDS SEE GHOSTS
# fetching  4089:   Above & Beyond
# fetching  4090:   ILOVEMAKONNEN
# fetching  4091:   Interpol
# fetching  4092:   Chrome Sparks
# fetching  4093:   Seven Lions
# fetching  4094:   Johnny Cash
# fetching  4095:   J. Davi$
# fetching  4096:   CSS
# fetching  4097:   Bowling For Soup
# fetching  4098:   Wes Walker
# fetching  4099:   CamelPhat
# fetching  4100:   Henry Jamison
# fetching  4101:   GOON DES GARCONS*
# fetching  4102:   Razika
# fetching  4103:   A Great Big World
# fetching  4104:   Bat For Lashes
# fetching  4105:   Metro Station
# fetching  4106:   Nikki Flores
# fetching  4107:   Phil Collins
# fetching  4108:   Grateful Dead
# fetching  4109:   MazZz
# fetching  4110:   Rudimental
# fetching  4111:   Digital Farm Animals
# fetching  4112:   DJ NorgeJodel
# fetching  4113:   G-Eazy
# fetching  4114:   Aretha Franklin
# fetching  4115:   Company - Into the Woods (Motion Picture Cast)
# fetching  4116:   Joe Jackson
# fetching  4117:   Tori Amos
# fetching  4118:   Galkin Evangelistic Team
# fetching  4119:   Waxahatchee
# fetching  4120:   Angela Lansbury
# fetching  4121:   The Romantics
# fetching  4122:   King Gizzard & The Lizard Wizard
# fetching  4123:   Jimmy Cliff
# fetching  4124:   Dimmu Borgir
# fetching  4125:   Rough Traders
# fetching  4126:   KC & The Sunshine Band
# fetching  4127:   Matt Maher
# fetching  4128:   Walker McGuire
# fetching  4129:   Wolfgang Amadeus Mozart
# something went wrong
# fetching  4130:   Rob $tone
# fetching  4131:   Marvin Gaye
# fetching  4132:   Camila Mendes
# fetching  4133:   Joe Esposito
# fetching  4134:   Denzel Curry
# fetching  4135:   Sylvan Esso
# fetching  4136:   The Pointer Sisters
# fetching  4137:   Kállay Saunders
# fetching  4138:   Cornershop
# fetching  4139:   Klovner I Kamp
# fetching  4140:   Jeff Hodge
# fetching  4141:   Tall Heights
# fetching  4142:   Kinobe
# fetching  4143:   Ashley Monroe
# fetching  4144:   Bryce Vine
# fetching  4145:   David Lynch
# fetching  4146:   Brando
# fetching  4147:   Pat Benatar
# fetching  4148:   Sigur Rós
# fetching  4149:   Nate Ruess
# fetching  4150:   Daikaiju
# fetching  4151:   Vidar Villa
# fetching  4152:   Jonah Marais
# fetching  4153:   Makaena Durias
# fetching  4154:   Novel
# fetching  4155:   Zac Brown
# fetching  4156:   Hollow Coves
# fetching  4157:   Reel Big Fish
# fetching  4158:   George Strait
# fetching  4159:   Gucci Mane
# fetching  4160:   Sananda Maitreya
# fetching  4161:   Empire of the Sun
# fetching  4162:   Gabry Ponte
# fetching  4163:   Tom Thum
# fetching  4164:   Celia Imrie
# fetching  4165:   Syd Matters
# fetching  4166:   Brain
# something went wrong
# fetching  4167:   Adventure Club
# fetching  4168:   Santigold
# fetching  4169:   Roscoe Dash
# fetching  4170:   Mt. Wolf
# fetching  4171:   The Wannadies
# fetching  4172:   Kozah
# fetching  4173:   Agust D
# fetching  4174:   Gazzara
# fetching  4175:   John Mark McMillan
# fetching  4176:   Wanz
# fetching  4177:   Nick Mulvey
# fetching  4178:   Joan Baez
# fetching  4179:   Chris Isaak
# fetching  4180:   Blue Wednesday
# fetching  4181:   Mavis Staples
# fetching  4182:   Madrugada
# fetching  4183:   Arkadi
# fetching  4184:   Young Thug
# fetching  4185:   Freddy Kalas
# fetching  4186:   Atomic Kitten
# fetching  4187:   Berliner Philharmoniker
# fetching  4188:   Barnes Blvd.
# fetching  4189:   Gwen Stefani
# fetching  4190:   Byklubben
# fetching  4191:   On The Rocks
# fetching  4192:   Joshua Radin
# fetching  4193:   Big Gigantic
# fetching  4194:   Tekkla
# fetching  4195:   Josh Garrels
# fetching  4196:   Colbie Caillat
# fetching  4197:   Nero
# fetching  4198:   The Band Perry
# fetching  4199:   M. Ward
# fetching  4200:   Damon Albarn
# fetching  4201:   Keri Hilson
# fetching  4202:   DJ Kue
# fetching  4203:   Andy Grammer
# fetching  4204:   MOONZz
# fetching  4205:   Dwayne Johnson
# fetching  4206:   Demon
# fetching  4207:   Lucas Grabeel
# fetching  4208:   Wild Rivers
# fetching  4209:   Aloe Blacc
# fetching  4210:   Cream
# fetching  4211:   D.O.E.
# fetching  4212:   Feenixpawl
# fetching  4213:   Cover Drive
# fetching  4214:   Steve Perry
# fetching  4215:   Kisschasy
# fetching  4216:   Jason Aldean
# fetching  4217:   Nine Days
# fetching  4218:   Justice
# fetching  4219:   Jaren Johnston
# fetching  4220:   Juanes
# fetching  4221:   Glee Cast
# fetching  4222:   Snow Patrol
# fetching  4223:   Paul Kenny
# fetching  4224:   Elvin Bishop
# fetching  4225:   Blind Pilot
# fetching  4226:   TWICE
# fetching  4227:   Patrick Watson
# fetching  4228:   Cosmo Pyke
# fetching  4229:   The Moth & The Flame
# fetching  4230:   Lucy Dacus
# fetching  4231:   The Prince Karma
# fetching  4232:   Hailee Steinfeld
# fetching  4233:   Brooks
# fetching  4234:   Marshmello
# fetching  4235:   Zella Day
# fetching  4236:   Qveen Herby
# fetching  4237:   Cedric Gervais
# fetching  4238:   CAKE
# fetching  4239:   Rudy Mancuso
# fetching  4240:   Loren Gray
# fetching  4241:   Jamie N Commons
# fetching  4242:   Field Division
# fetching  4243:   Kenji Club
# fetching  4244:   Blackchords
# fetching  4245:   The Weather Station
# fetching  4246:   John Rzeznik
# fetching  4247:   Dragonette
# fetching  4248:   Matt and Kim
# fetching  4249:   The Highwaymen
# fetching  4250:   Miike Snow
# fetching  4251:   David Hazeltine
# fetching  4252:   Sir Mix-A-Lot
# fetching  4253:   Lennon & Maisy
# fetching  4254:   Miguel Serrano
# fetching  4255:   Kaoma
# fetching  4256:   Pantera
# fetching  4257:   Travis
# fetching  4258:   Chris Baco
# fetching  4259:   Giorgio Tuinfort
# fetching  4260:   Emerson, Lake & Palmer
# fetching  4261:   Gary Clark Jr.
# fetching  4262:   Vladimir Horowitz
# fetching  4263:   Dave Van Ronk
# fetching  4264:   White Zombie
# fetching  4265:   ODA
# fetching  4266:   Pia Mia
# fetching  4267:   Melanie Martinez
# fetching  4268:   Spencer & Antfood
# fetching  4269:   Juanita Grande
# fetching  4270:   N.W.A.
# fetching  4271:   Under The Influence of Giants
# fetching  4272:   Gustavo Santaolalla
# fetching  4273:   Little Feat
# fetching  4274:   The Ataris
# fetching  4275:   Irfane
# fetching  4276:   Midranger
# fetching  4277:   The Monkees
# fetching  4278:   Mr. Scruff
# fetching  4279:   Ini Kamoze
# fetching  4280:   Michael Borgstede
# fetching  4281:   Jimmy Buffett
# fetching  4282:   Good Charlotte
# fetching  4283:   Michael Kiwanuka
# fetching  4284:   Chuck Berry
# fetching  4285:   Wolf Gang
# fetching  4286:   The Soronprfbs
# fetching  4287:   Madge
# fetching  4288:   The Temper Trap
# fetching  4289:   Jonas Brothers
# fetching  4290:   Buzz McCoy
# fetching  4291:   Rusted Root
# fetching  4292:   Visitor
# fetching  4293:   Epica
# fetching  4294:   Disturbed
# fetching  4295:   Amsterdam Sinfonietta
# fetching  4296:   The Devil Makes Three
# fetching  4297:   Cobra Starship
# fetching  4298:   Viceroy
# fetching  4299:   Journey
# fetching  4300:   Marc Benjamin
# fetching  4301:   Simple Minds
# fetching  4302:   Third Day
# fetching  4303:   KEiiNO
# fetching  4304:   Ed Harcourt
# fetching  4305:   Heretic Klick
# fetching  4306:   DJ Veggie
# fetching  4307:   King Charles
# fetching  4308:   India.Arie
# fetching  4309:   The Antlers
# fetching  4310:   Chris Willis
# fetching  4311:   Aesop Rock
# fetching  4312:   Smooth Jazz Sax Instrumentals
# fetching  4313:   Fyfe
# fetching  4314:   Cody G
# fetching  4315:   Agalloch
# fetching  4316:   Sam & Dave
# fetching  4317:   Brandon Flowers
# fetching  4318:   Adam Christopher
# fetching  4319:   Jimmy Ray
# fetching  4320:   Edvard Grieg
# fetching  4321:   Jack in Water
# fetching  4322:   Bjonr
# fetching  4323:   Sasha Alex Sloan
# fetching  4324:   Death Grips
# fetching  4325:   Tom Odell
# fetching  4326:   Britney Spears
# fetching  4327:   The Jam
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_91290/252816875.py in <module>
#      32                 print('something went wrong')
#      33                 continue
# ---> 34     songs.reset_index(drop=True).to_csv(f'csv_data/willis_{counter}.csv', index=False)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692     # Only for write methods
#     693     if "r" not in mode and is_path:
# --> 694         check_parent_directory(str(handle))
#     695
#     696     if compression:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in check_parent_directory(path)
#     566     parent = Path(path).parent
#     567     if not parent.is_dir():
# --> 568         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     569
#     570
#
# OSError: Cannot save file into a non-existent directory: 'csv_data'
